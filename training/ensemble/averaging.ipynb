# %%
# 基本的なライブラリ
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import random
import os

# モデル関連
import lightgbm as lgb
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb
from pytorch_tabnet.tab_model import TabNetRegressor
import torch
from sklearn.metrics import mean_absolute_percentage_error
from pytorch_tabnet.tab_model import TabNetRegressor
import torch
from sklearn.metrics import mean_absolute_percentage_error

# モデル評価・前処理関連
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve, cross_val_score, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# ハイパーパラメータ最適化関連
import optuna
from optuna.integration import LightGBMPruningCallback, XGBoostPruningCallback
import optuna.visualization as vis

# その他のユーティリティ
import shap
import joblib

# 乱数のシードを固定
def torch_fix_seed(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = 'true'
    os.environ['TF_CUDNN_DETERMINISTIC'] = 'true'
    
    # Python random
    random.seed(seed)
    # Numpy
    np.random.seed(seed)
    # Pytorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False
    
torch_fix_seed()

# 警告を無視
warnings.filterwarnings("ignore")

# %%
# データの読み込み
all_data = pd.read_csv('../../data_processed/all_data.csv')

train_data = all_data[0:27532]
X = train_data.drop(['price'], axis=1)
y = train_data['price']

# データの分割
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
def catboost_params(trial):
    return {
        'depth': trial.suggest_int('cat_depth', 4, 16),
        'learning_rate': trial.suggest_loguniform('cat_learning_rate', 0.00001, 0.1),
        'iterations': trial.suggest_int('cat_iterations', 50, 2000),
        'l2_leaf_reg': trial.suggest_int('cat_l2_leaf_reg', 1, 20),
        'border_count': trial.suggest_categorical('cat_border_count', [32, 64, 128, 256, 512]),
        'thread_count': 4
    }

def lightgbm_params(trial):
    return {
        'num_leaves': trial.suggest_int('lgb_num_leaves', 10, 50),
        'max_depth': trial.suggest_int('lgb_max_depth', 2, 7),
        'learning_rate': trial.suggest_float('lgb_learning_rate', 0.001, 0.1, log=True),
        'n_estimators': trial.suggest_int('lgb_n_estimators', 50, 100),
        'min_child_samples': trial.suggest_int('lgb_min_child_samples', 20, 100),
        'subsample': trial.suggest_float('lgb_subsample', 0.5, 1.0, step=0.1),
        'colsample_bytree': trial.suggest_float('lgb_colsample_bytree', 0.4, 1.0, step=0.1),
        'reg_alpha': trial.suggest_float('lgb_reg_alpha', 0.0, 0.5, step=0.1),
        'reg_lambda': trial.suggest_float('lgb_reg_lambda', 0.0, 0.5, step=0.1),
        'force_col_wise': True,  
        'verbose': -1  # 出力を無効にする
    }

def xgboost_params(trial):
    return {
        'max_depth': trial.suggest_int('xgb_max_depth', 3, 9),
        'learning_rate': trial.suggest_loguniform('xgb_learning_rate', 0.001, 0.1),
        'n_estimators': trial.suggest_int('xgb_n_estimators', 50, 1000),
        'min_child_weight': trial.suggest_int('xgb_min_child_weight', 1, 10),
        'subsample': trial.suggest_float('xgb_subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('xgb_colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('xgb_reg_alpha', 0.0, 0.5),
        'reg_lambda': trial.suggest_float('xgb_reg_lambda', 0.0, 0.5),
        'verbosity': 0,  # 出力を無効にする
        'objective': 'reg:squarederror',
        'booster': trial.suggest_categorical('xgb_booster', ['gbtree', 'gblinear', 'dart']),
        'tree_method': 'hist',
        'seed': 42
    }

# def tabnet_params(trial):
#     return {
#         'n_d': trial.suggest_int('tab_n_d', 8, 64),
#         'n_a': trial.suggest_int('tab_n_a', 8, 64),
#         'n_steps': trial.suggest_int('tab_n_steps', 3, 10),
#         'gamma': trial.suggest_float('tab_gamma', 1.0, 2.0),
#         'n_independent': trial.suggest_int('tab_n_independent', 1, 5),
#         'n_shared': trial.suggest_int('tab_n_shared', 1, 5),
#         'lambda_sparse': trial.suggest_float('tab_lambda_sparse', 1e-5, 1e-1, log=True),
#         'optimizer_fn': torch.optim.Adam,
#         'scheduler_params': {"step_size":10, "gamma":0.9},
#         'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#         'verbose': 0
#     }

def randomforest_params(trial):
    return  {
            'n_estimators': trial.suggest_int('rdf_n_estimators', 2, 150),
            'max_depth': trial.suggest_int('rdf_max_depth', 1, 32, log=True),
            'min_samples_split': trial.suggest_float('rdf_min_samples_split', 0.1, 1),
            'min_samples_leaf': trial.suggest_float('rdf_min_samples_leaf', 0.1, 0.5),                
            'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2']),
            'bootstrap': trial.suggest_categorical('rdf_bootstrap', [True, False]),
            'random_state': 42
    }
    
def objective(trial):
    # 交差検証の設定
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    mape_scores = []

    for train_idx, val_idx in kf.split(X, y):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        # CatBoost
        cat_model = CatBoostRegressor(**catboost_params(trial), random_seed=42, verbose=0)
        cat_model.fit(X_train, y_train, 
                      eval_set=[(X_val, y_val)], 
                      early_stopping_rounds=10, 
                      cat_features=[])
        
        # LightGBM
        lgb_model = LGBMRegressor(**lightgbm_params(trial), random_state=42)
        lgb_model.fit(X_train, y_train, eval_metric='mape', 
                      eval_set=[(X_val, y_val)],
                      callbacks=[LightGBMPruningCallback(trial, 'l2')]) # 出力を無効にする
        
        # XGBoost
        dval = xgb.DMatrix(X_val, label=y_val)
        xgb_model = xgb.train(xgboost_params(trial), dval, evals=[(dval, 'eval')], 
                              early_stopping_rounds=10, 
                              callbacks=[XGBoostPruningCallback(trial, 'eval-rmse')], verbose_eval=False)
        
        # # tannet
        # tab_model = TabNetRegressor(**tabnet_params(trial))
        # tab_model.fit(X_train.values, y_train.values.reshape(-1, 1), 
        #               eval_set=[(X_val.values, y_val.values.reshape(-1, 1))])
        
        # RandomForest
        rdf_model = RandomForestRegressor(**randomforest_params(trial))
        rdf_model.fit(X_train, y_train)
        
        # 各モデルの予測を取得
        cat_preds = cat_model.predict(X_val)
        lgb_preds = lgb_model.predict(X_val)
        dval = xgb.DMatrix(X_val)
        xgb_preds = xgb_model.predict(dval)
        # tab_preds = tab_model.predict(X_val.values)
        rdf_preds = rdf_model.predict(X_val)
        
        # 5つのモデルの予測を平均して最終的な予測を得る
        final_preds = (cat_preds + lgb_preds + xgb_preds  + rdf_preds) / 4 #+ tab_preds
       
        mape = mean_absolute_percentage_error(y_val, final_preds)
        mape_scores.append(mape)
    
    return sum(mape_scores) / n_splits

# %%
# optunaのスタディを作成
study = optuna.create_study(direction="minimize")

# 初期のトライアルを追加
study.enqueue_trial({'cat_depth': 8, 'cat_learning_rate': 0.00651224680897653, 'cat_iterations': 1821, 'cat_l2_leaf_reg': 5, 'cat_border_count': 256, 'lgb_num_leaves': 50, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.091099381427228, 'lgb_n_estimators': 89, 'lgb_min_child_samples': 54, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001031754501018457, 'xgb_n_estimators': 235, 'xgb_min_child_weight': 5, 'xgb_subsample': 0.9871415109340169, 'xgb_colsample_bytree': 0.6444006263081316, 'xgb_reg_alpha': 0.11089498111190996, 'xgb_reg_lambda': 0.30379454797790195, 'xgb_booster': 'dart', 'rdf_n_estimators': 6, 'rdf_max_depth': 11, 'rdf_min_samples_split': 0.7610018174059954, 'rdf_min_samples_leaf': 0.10024596126396466, 'max_features': 'auto', 'rdf_bootstrap': False})

# 最適化を実行  
study.optimize(objective, 
               n_trials=200, 
               timeout=60*60*5, 
               n_jobs=1, 
               gc_after_trial=False, 
               show_progress_bar=True)  # 合計のトライアル数とタイムアウトを調整

print('Value: ', study.best_trial.value)
print('Best trial:', study.best_trial.params)
# Out:
# [I 2023-08-18 15:08:35,885] A new study created in memory with name: no-name-7fcaf4c3-4351-4726-a019-ee517527161c
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2023-08-18 15:09:03,689] Trial 0 finished with value: 0.5393012455634046 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.00651224680897653, 'cat_iterations': 1821, 'cat_l2_leaf_reg': 5, 'cat_border_count': 256, 'lgb_num_leaves': 50, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.091099381427228, 'lgb_n_estimators': 89, 'lgb_min_child_samples': 54, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001031754501018457, 'xgb_n_estimators': 235, 'xgb_min_child_weight': 5, 'xgb_subsample': 0.9871415109340169, 'xgb_colsample_bytree': 0.6444006263081316, 'xgb_reg_alpha': 0.11089498111190996, 'xgb_reg_lambda': 0.30379454797790195, 'xgb_booster': 'dart', 'rdf_n_estimators': 6, 'rdf_max_depth': 11, 'rdf_min_samples_split': 0.7610018174059954, 'rdf_min_samples_leaf': 0.10024596126396466, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 15:09:15,720] Trial 1 finished with value: 0.949603393538127 and parameters: {'cat_depth': 6, 'cat_learning_rate': 0.01588513199500461, 'cat_iterations': 930, 'cat_l2_leaf_reg': 8, 'cat_border_count': 64, 'lgb_num_leaves': 15, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.00807109362687687, 'lgb_n_estimators': 84, 'lgb_min_child_samples': 59, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.05231219963214001, 'xgb_n_estimators': 827, 'xgb_min_child_weight': 5, 'xgb_subsample': 0.9000277688336751, 'xgb_colsample_bytree': 0.6834806303531817, 'xgb_reg_alpha': 0.14769607355470132, 'xgb_reg_lambda': 0.3560131114260165, 'xgb_booster': 'gblinear', 'rdf_n_estimators': 61, 'rdf_max_depth': 17, 'rdf_min_samples_split': 0.5631432659664406, 'rdf_min_samples_leaf': 0.48527745794489274, 'max_features': 'auto', 'rdf_bootstrap': True}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 15:09:37,735] Trial 2 finished with value: 0.8915503593977476 and parameters: {'cat_depth': 7, 'cat_learning_rate': 5.185869044645837e-05, 'cat_iterations': 1147, 'cat_l2_leaf_reg': 10, 'cat_border_count': 32, 'lgb_num_leaves': 38, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.02550713129400968, 'lgb_n_estimators': 80, 'lgb_min_child_samples': 70, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.009081246458878705, 'xgb_n_estimators': 207, 'xgb_min_child_weight': 6, 'xgb_subsample': 0.5489659650000319, 'xgb_colsample_bytree': 0.9044769912574421, 'xgb_reg_alpha': 0.22571670573325847, 'xgb_reg_lambda': 0.1314405767157827, 'xgb_booster': 'gblinear', 'rdf_n_estimators': 140, 'rdf_max_depth': 2, 'rdf_min_samples_split': 0.5333235323263493, 'rdf_min_samples_leaf': 0.2617369865868211, 'max_features': 'log2', 'rdf_bootstrap': True}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 15:10:09,384] Trial 3 finished with value: 0.6625427576879287 and parameters: {'cat_depth': 4, 'cat_learning_rate': 0.0006389711776436577, 'cat_iterations': 1899, 'cat_l2_leaf_reg': 2, 'cat_border_count': 512, 'lgb_num_leaves': 11, 'lgb_max_depth': 3, 'lgb_learning_rate': 0.019104386163511216, 'lgb_n_estimators': 67, 'lgb_min_child_samples': 29, 'lgb_subsample': 0.9, 'lgb_colsample_bytree': 0.5, 'lgb_reg_alpha': 0.2, 'lgb_reg_lambda': 0.4, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.0017890198497679797, 'xgb_n_estimators': 278, 'xgb_min_child_weight': 6, 'xgb_subsample': 0.6759750123263515, 'xgb_colsample_bytree': 0.5149357332929959, 'xgb_reg_alpha': 0.38398041831041346, 'xgb_reg_lambda': 0.4639150245372906, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 137, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.49859406406597895, 'rdf_min_samples_leaf': 0.1582824435685422, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:23:30,882] Trial 4 finished with value: 0.8437060676990287 and parameters: {'cat_depth': 16, 'cat_learning_rate': 0.0036782291017322588, 'cat_iterations': 1767, 'cat_l2_leaf_reg': 19, 'cat_border_count': 512, 'lgb_num_leaves': 38, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.07472616952094364, 'lgb_n_estimators': 88, 'lgb_min_child_samples': 86, 'lgb_subsample': 1.0, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.019045080619237743, 'xgb_n_estimators': 75, 'xgb_min_child_weight': 6, 'xgb_subsample': 0.6287341176458924, 'xgb_colsample_bytree': 0.8356639877930535, 'xgb_reg_alpha': 0.15661402265718155, 'xgb_reg_lambda': 0.2836079404238266, 'xgb_booster': 'gblinear', 'rdf_n_estimators': 112, 'rdf_max_depth': 14, 'rdf_min_samples_split': 0.42434575891029325, 'rdf_min_samples_leaf': 0.3314568302349773, 'max_features': 'log2', 'rdf_bootstrap': True}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:23:35,048] Trial 5 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:24:12,531] Trial 6 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:26:08,430] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:26:37,029] Trial 8 pruned. Trial was pruned at iteration 67.
# [I 2023-08-18 16:26:39,941] Trial 9 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:26:41,495] Trial 10 pruned. Trial was pruned at iteration 80.
# [I 2023-08-18 16:26:46,025] Trial 11 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:27:08,338] Trial 12 pruned. Trial was pruned at iteration 67.
# [I 2023-08-18 16:27:39,274] Trial 13 finished with value: 0.5509778025771758 and parameters: {'cat_depth': 10, 'cat_learning_rate': 0.011313896512933366, 'cat_iterations': 1520, 'cat_l2_leaf_reg': 4, 'cat_border_count': 256, 'lgb_num_leaves': 22, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.09853220749742894, 'lgb_n_estimators': 70, 'lgb_min_child_samples': 21, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.5, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001078965589741395, 'xgb_n_estimators': 410, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9970593878443644, 'xgb_colsample_bytree': 0.526047264107303, 'xgb_reg_alpha': 0.4623197973840516, 'xgb_reg_lambda': 0.4892535820545822, 'xgb_booster': 'dart', 'rdf_n_estimators': 3, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9001505836364285, 'rdf_min_samples_leaf': 0.10001391709080176, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:27:43,840] Trial 14 pruned. Trial was pruned at iteration 88.
# [I 2023-08-18 16:27:54,987] Trial 15 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:27:55,832] Trial 16 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:27:58,913] Trial 17 pruned. Trial was pruned at iteration 84.
# [I 2023-08-18 16:28:27,400] Trial 18 pruned. Trial was pruned at iteration 67.
# [I 2023-08-18 16:28:30,890] Trial 19 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:28:42,448] Trial 20 pruned. Trial was pruned at iteration 67.
# [I 2023-08-18 16:28:47,941] Trial 21 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:28:56,006] Trial 22 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:28:59,753] Trial 23 pruned. Trial was pruned at iteration 2.
# [I 2023-08-18 16:29:07,138] Trial 24 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:29:24,012] Trial 25 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:29:41,025] Trial 26 finished with value: 0.555006453249909 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.009158610475867503, 'cat_iterations': 1909, 'cat_l2_leaf_reg': 3, 'cat_border_count': 512, 'lgb_num_leaves': 28, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.08815088515515059, 'lgb_n_estimators': 53, 'lgb_min_child_samples': 42, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.2, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001042229800794042, 'xgb_n_estimators': 366, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9983589920360815, 'xgb_colsample_bytree': 0.5013253057206719, 'xgb_reg_alpha': 0.46704739054332667, 'xgb_reg_lambda': 0.4580490301157969, 'xgb_booster': 'dart', 'rdf_n_estimators': 2, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9367643016433751, 'rdf_min_samples_leaf': 0.10600704318736681, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:29:45,356] Trial 27 pruned. Trial was pruned at iteration 84.
# [I 2023-08-18 16:29:47,255] Trial 28 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:29:50,304] Trial 29 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:29:56,504] Trial 30 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:30:01,581] Trial 31 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:30:16,924] Trial 32 finished with value: 0.5501478865678473 and parameters: {'cat_depth': 5, 'cat_learning_rate': 0.011486055826861664, 'cat_iterations': 1876, 'cat_l2_leaf_reg': 2, 'cat_border_count': 512, 'lgb_num_leaves': 23, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.09985685763609171, 'lgb_n_estimators': 61, 'lgb_min_child_samples': 40, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.2, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010323496825383257, 'xgb_n_estimators': 385, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9983861421090247, 'xgb_colsample_bytree': 0.505520143831416, 'xgb_reg_alpha': 0.46816354402174803, 'xgb_reg_lambda': 0.49148924775831193, 'xgb_booster': 'dart', 'rdf_n_estimators': 2, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9658496439914108, 'rdf_min_samples_leaf': 0.10289699964731518, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:30:19,237] Trial 33 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:30:43,968] Trial 34 finished with value: 0.5519115590658 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.006022334859477613, 'cat_iterations': 1588, 'cat_l2_leaf_reg': 5, 'cat_border_count': 512, 'lgb_num_leaves': 35, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.09482209328519156, 'lgb_n_estimators': 62, 'lgb_min_child_samples': 49, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010818927041706585, 'xgb_n_estimators': 487, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9912840531766612, 'xgb_colsample_bytree': 0.5017927508743618, 'xgb_reg_alpha': 0.48687839406942324, 'xgb_reg_lambda': 0.49251322133721986, 'xgb_booster': 'dart', 'rdf_n_estimators': 4, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9597563933046498, 'rdf_min_samples_leaf': 0.10058883759712299, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:30:47,559] Trial 35 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:30:50,072] Trial 36 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:11,481] Trial 37 finished with value: 0.5599692350829957 and parameters: {'cat_depth': 6, 'cat_learning_rate': 0.0027408220143826448, 'cat_iterations': 1436, 'cat_l2_leaf_reg': 8, 'cat_border_count': 32, 'lgb_num_leaves': 41, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.09943778224133551, 'lgb_n_estimators': 60, 'lgb_min_child_samples': 55, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.0, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001017207046913724, 'xgb_n_estimators': 506, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9996980414900223, 'xgb_colsample_bytree': 0.5287230808974824, 'xgb_reg_alpha': 0.49527087427768157, 'xgb_reg_lambda': 0.4766210169773857, 'xgb_booster': 'dart', 'rdf_n_estimators': 2, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9477796695636294, 'rdf_min_samples_leaf': 0.10152587226119915, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:31:18,268] Trial 38 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:19,222] Trial 39 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:22,343] Trial 40 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:27,040] Trial 41 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:28,946] Trial 42 pruned. Trial was pruned at iteration 45.
# [I 2023-08-18 16:31:36,954] Trial 43 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:40,660] Trial 44 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:42,822] Trial 45 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:47,654] Trial 46 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:31:54,337] Trial 47 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:32:00,577] Trial 48 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:32:04,557] Trial 49 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:32:09,611] Trial 50 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:32:13,675] Trial 51 pruned. Trial was pruned at iteration 29.
# [I 2023-08-18 16:32:33,495] Trial 52 finished with value: 0.5508957552833432 and parameters: {'cat_depth': 6, 'cat_learning_rate': 0.00655554202834538, 'cat_iterations': 1465, 'cat_l2_leaf_reg': 7, 'cat_border_count': 32, 'lgb_num_leaves': 46, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.09867655658338938, 'lgb_n_estimators': 64, 'lgb_min_child_samples': 50, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.0, 'lgb_reg_lambda': 0.0, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010002976493759144, 'xgb_n_estimators': 465, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.992817741003479, 'xgb_colsample_bytree': 0.5021153099736971, 'xgb_reg_alpha': 0.4959818710686181, 'xgb_reg_lambda': 0.49605930784967267, 'xgb_booster': 'dart', 'rdf_n_estimators': 2, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9565698740374758, 'rdf_min_samples_leaf': 0.10130349793249312, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:32:38,167] Trial 53 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:34:39,235] Trial 54 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:34:43,022] Trial 55 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:34:53,778] Trial 56 finished with value: 0.547679643890494 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.018300558314831565, 'cat_iterations': 1642, 'cat_l2_leaf_reg': 7, 'cat_border_count': 128, 'lgb_num_leaves': 45, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.08669809273609444, 'lgb_n_estimators': 64, 'lgb_min_child_samples': 58, 'lgb_subsample': 0.6, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010215835942360182, 'xgb_n_estimators': 445, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9942029659856062, 'xgb_colsample_bytree': 0.5029522369919422, 'xgb_reg_alpha': 0.4858931870339629, 'xgb_reg_lambda': 0.4903281052906877, 'xgb_booster': 'dart', 'rdf_n_estimators': 4, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9595967210327319, 'rdf_min_samples_leaf': 0.10231968209205092, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:34:55,733] Trial 57 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:01,143] Trial 58 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:02,583] Trial 59 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:07,175] Trial 60 finished with value: 0.5455164516372509 and parameters: {'cat_depth': 5, 'cat_learning_rate': 0.06363657741333915, 'cat_iterations': 1662, 'cat_l2_leaf_reg': 9, 'cat_border_count': 128, 'lgb_num_leaves': 46, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09961582998587999, 'lgb_n_estimators': 80, 'lgb_min_child_samples': 64, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010332806616897322, 'xgb_n_estimators': 484, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9851662195906901, 'xgb_colsample_bytree': 0.5094698869568668, 'xgb_reg_alpha': 0.4977172867758769, 'xgb_reg_lambda': 0.49667615491425443, 'xgb_booster': 'dart', 'rdf_n_estimators': 3, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9582293076665231, 'rdf_min_samples_leaf': 0.10361273064749703, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:35:08,069] Trial 61 pruned. Trial was pruned at iteration 57.
# [I 2023-08-18 16:35:09,858] Trial 62 pruned. Trial was pruned at iteration 84.
# [I 2023-08-18 16:35:10,577] Trial 63 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:12,808] Trial 64 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:19,882] Trial 65 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:22,512] Trial 66 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:23,212] Trial 67 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:30,536] Trial 68 finished with value: 0.5480012055203842 and parameters: {'cat_depth': 9, 'cat_learning_rate': 0.04290235389870499, 'cat_iterations': 1362, 'cat_l2_leaf_reg': 7, 'cat_border_count': 256, 'lgb_num_leaves': 43, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09908703452332429, 'lgb_n_estimators': 61, 'lgb_min_child_samples': 90, 'lgb_subsample': 0.6, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010103049218032018, 'xgb_n_estimators': 502, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9981522477364165, 'xgb_colsample_bytree': 0.5001440604053264, 'xgb_reg_alpha': 0.4879585354118113, 'xgb_reg_lambda': 0.4994482747027742, 'xgb_booster': 'dart', 'rdf_n_estimators': 3, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9570125808275642, 'rdf_min_samples_leaf': 0.10245998640484925, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:35:32,175] Trial 69 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:33,281] Trial 70 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:40,057] Trial 71 finished with value: 0.5485197353164233 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.036751408738923665, 'cat_iterations': 1464, 'cat_l2_leaf_reg': 5, 'cat_border_count': 256, 'lgb_num_leaves': 41, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.0902863047724529, 'lgb_n_estimators': 61, 'lgb_min_child_samples': 82, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010790118757089315, 'xgb_n_estimators': 495, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.998752207587662, 'xgb_colsample_bytree': 0.5012434130824154, 'xgb_reg_alpha': 0.4935712606850656, 'xgb_reg_lambda': 0.4948658063508139, 'xgb_booster': 'dart', 'rdf_n_estimators': 4, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9677739688072252, 'rdf_min_samples_leaf': 0.10100454223133602, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:35:47,202] Trial 72 finished with value: 0.5474997445576635 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.0389210905172639, 'cat_iterations': 1449, 'cat_l2_leaf_reg': 8, 'cat_border_count': 256, 'lgb_num_leaves': 41, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09967358275165673, 'lgb_n_estimators': 60, 'lgb_min_child_samples': 90, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001036032503728322, 'xgb_n_estimators': 494, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9960416265682608, 'xgb_colsample_bytree': 0.5026562545695796, 'xgb_reg_alpha': 0.4977803400641646, 'xgb_reg_lambda': 0.4995724267590506, 'xgb_booster': 'dart', 'rdf_n_estimators': 3, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9639659920016936, 'rdf_min_samples_leaf': 0.10106748316863814, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:35:48,644] Trial 73 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:54,898] Trial 74 finished with value: 0.5481169785315435 and parameters: {'cat_depth': 9, 'cat_learning_rate': 0.06619100832083996, 'cat_iterations': 1020, 'cat_l2_leaf_reg': 10, 'cat_border_count': 256, 'lgb_num_leaves': 42, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09983339824823262, 'lgb_n_estimators': 58, 'lgb_min_child_samples': 90, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010383683743917438, 'xgb_n_estimators': 552, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.993372448991471, 'xgb_colsample_bytree': 0.5016152309372732, 'xgb_reg_alpha': 0.4890690736862605, 'xgb_reg_lambda': 0.4973944622427069, 'xgb_booster': 'dart', 'rdf_n_estimators': 7, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9799148309419116, 'rdf_min_samples_leaf': 0.10228734961211107, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:35:56,029] Trial 75 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:57,537] Trial 76 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:58,754] Trial 77 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:35:59,654] Trial 78 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:00,828] Trial 79 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:01,885] Trial 80 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:11,297] Trial 81 finished with value: 0.5467496975490425 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.02334668483602641, 'cat_iterations': 1485, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 45, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09969178090092559, 'lgb_n_estimators': 64, 'lgb_min_child_samples': 92, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010312568073226364, 'xgb_n_estimators': 523, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9958029178062925, 'xgb_colsample_bytree': 0.5009900062797156, 'xgb_reg_alpha': 0.48920356169285556, 'xgb_reg_lambda': 0.49367011544662376, 'xgb_booster': 'dart', 'rdf_n_estimators': 5, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9881508335585895, 'rdf_min_samples_leaf': 0.10033790066935541, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:36:27,537] Trial 82 finished with value: 0.548600375191828 and parameters: {'cat_depth': 10, 'cat_learning_rate': 0.029142221200974396, 'cat_iterations': 1101, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 47, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.08965167594534706, 'lgb_n_estimators': 63, 'lgb_min_child_samples': 93, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010585488840036395, 'xgb_n_estimators': 562, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9987063024058596, 'xgb_colsample_bytree': 0.5018581590651656, 'xgb_reg_alpha': 0.49705056185328944, 'xgb_reg_lambda': 0.49967793421227863, 'xgb_booster': 'dart', 'rdf_n_estimators': 16, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9948775757593494, 'rdf_min_samples_leaf': 0.10349222340564841, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:36:31,179] Trial 83 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:41,623] Trial 84 finished with value: 0.5478888064680268 and parameters: {'cat_depth': 9, 'cat_learning_rate': 0.03244826854204582, 'cat_iterations': 836, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 47, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.08951018602517494, 'lgb_n_estimators': 66, 'lgb_min_child_samples': 87, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001037455002291375, 'xgb_n_estimators': 639, 'xgb_min_child_weight': 2, 'xgb_subsample': 0.9672480318215513, 'xgb_colsample_bytree': 0.5017755196327048, 'xgb_reg_alpha': 0.49931169005569226, 'xgb_reg_lambda': 0.48817362269474346, 'xgb_booster': 'dart', 'rdf_n_estimators': 25, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9877639187727237, 'rdf_min_samples_leaf': 0.1024815067001743, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:36:43,482] Trial 85 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:52,878] Trial 86 finished with value: 0.5475504393061116 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.03287977821081459, 'cat_iterations': 896, 'cat_l2_leaf_reg': 7, 'cat_border_count': 256, 'lgb_num_leaves': 42, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09968219534956821, 'lgb_n_estimators': 61, 'lgb_min_child_samples': 83, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.001583904848526144, 'xgb_n_estimators': 641, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.937167849328484, 'xgb_colsample_bytree': 0.5783303450754056, 'xgb_reg_alpha': 0.019486840669123262, 'xgb_reg_lambda': 0.4993294902377783, 'xgb_booster': 'dart', 'rdf_n_estimators': 28, 'rdf_max_depth': 8, 'rdf_min_samples_split': 0.9990900440105062, 'rdf_min_samples_leaf': 0.13344471655546183, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:36:54,148] Trial 87 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:55,954] Trial 88 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:56,553] Trial 89 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:36:57,934] Trial 90 pruned. Trial was pruned at iteration 1.
# [I 2023-08-18 16:37:06,425] Trial 91 finished with value: 0.5485296453326779 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.03510817232086034, 'cat_iterations': 934, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 43, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09172035205229537, 'lgb_n_estimators': 60, 'lgb_min_child_samples': 82, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010240724518865683, 'xgb_n_estimators': 640, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9469806388308659, 'xgb_colsample_bytree': 0.5024775127909104, 'xgb_reg_alpha': 0.021674136104876247, 'xgb_reg_lambda': 0.49577545902937203, 'xgb_booster': 'dart', 'rdf_n_estimators': 30, 'rdf_max_depth': 9, 'rdf_min_samples_split': 0.9918590773618646, 'rdf_min_samples_leaf': 0.10202385492054511, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:37:08,615] Trial 92 pruned. Trial was pruned at iteration 23.
# [I 2023-08-18 16:37:59,831] Trial 93 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:00,656] Trial 94 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:01,384] Trial 95 pruned. Trial was pruned at iteration 25.
# [I 2023-08-18 16:38:02,783] Trial 96 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:04,380] Trial 97 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:29,560] Trial 98 finished with value: 0.5504415027153546 and parameters: {'cat_depth': 10, 'cat_learning_rate': 0.014507209994118942, 'cat_iterations': 1464, 'cat_l2_leaf_reg': 7, 'cat_border_count': 128, 'lgb_num_leaves': 40, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.0972842056948347, 'lgb_n_estimators': 56, 'lgb_min_child_samples': 92, 'lgb_subsample': 0.6, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0015574708293956854, 'xgb_n_estimators': 657, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9323747910944911, 'xgb_colsample_bytree': 0.5768275464868697, 'xgb_reg_alpha': 0.4996769093724791, 'xgb_reg_lambda': 0.4932801836411415, 'xgb_booster': 'dart', 'rdf_n_estimators': 27, 'rdf_max_depth': 7, 'rdf_min_samples_split': 0.9983904620996439, 'rdf_min_samples_leaf': 0.13481444735365947, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:38:30,693] Trial 99 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:33,019] Trial 100 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:34,498] Trial 101 pruned. Trial was pruned at iteration 36.
# [I 2023-08-18 16:38:40,556] Trial 102 finished with value: 0.5478355596268403 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.0683399896818147, 'cat_iterations': 833, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 46, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09964902665387187, 'lgb_n_estimators': 58, 'lgb_min_child_samples': 79, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010123284843751971, 'xgb_n_estimators': 639, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9464231361771032, 'xgb_colsample_bytree': 0.5015589015590463, 'xgb_reg_alpha': 0.027231462232031815, 'xgb_reg_lambda': 0.4991109497510658, 'xgb_booster': 'dart', 'rdf_n_estimators': 32, 'rdf_max_depth': 9, 'rdf_min_samples_split': 0.9975635215935197, 'rdf_min_samples_leaf': 0.10195621799756704, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:38:41,908] Trial 103 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:42,902] Trial 104 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:49,398] Trial 105 finished with value: 0.547631995975843 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.043594765670150575, 'cat_iterations': 738, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 45, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.0989635207719317, 'lgb_n_estimators': 57, 'lgb_min_child_samples': 79, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010092007808689223, 'xgb_n_estimators': 633, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9487560326636538, 'xgb_colsample_bytree': 0.5599749485724707, 'xgb_reg_alpha': 0.0032245732119744117, 'xgb_reg_lambda': 0.49368059194053104, 'xgb_booster': 'dart', 'rdf_n_estimators': 24, 'rdf_max_depth': 10, 'rdf_min_samples_split': 0.991408192188408, 'rdf_min_samples_leaf': 0.10018837559886463, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:38:53,268] Trial 106 finished with value: 0.55890105688155 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.0856826741224232, 'cat_iterations': 629, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 48, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09954888933847922, 'lgb_n_estimators': 55, 'lgb_min_child_samples': 78, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.001617848884170701, 'xgb_n_estimators': 635, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.940616441596447, 'xgb_colsample_bytree': 0.5754668485293639, 'xgb_reg_alpha': 0.0076112524177383515, 'xgb_reg_lambda': 0.4274133989140635, 'xgb_booster': 'dart', 'rdf_n_estimators': 29, 'rdf_max_depth': 9, 'rdf_min_samples_split': 0.9975538265234104, 'rdf_min_samples_leaf': 0.13815972586179798, 'max_features': 'sqrt', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:38:54,231] Trial 107 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:55,119] Trial 108 pruned. Trial was pruned at iteration 39.
# [I 2023-08-18 16:38:56,930] Trial 109 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:38:58,827] Trial 110 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:00,040] Trial 111 pruned. Trial was pruned at iteration 26.
# [I 2023-08-18 16:39:01,596] Trial 112 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:03,033] Trial 113 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:04,268] Trial 114 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:06,061] Trial 115 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:10,488] Trial 116 finished with value: 0.5498331058487058 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.05847832070381033, 'cat_iterations': 127, 'cat_l2_leaf_reg': 8, 'cat_border_count': 128, 'lgb_num_leaves': 41, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09161469257746663, 'lgb_n_estimators': 58, 'lgb_min_child_samples': 89, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010125023499880025, 'xgb_n_estimators': 579, 'xgb_min_child_weight': 2, 'xgb_subsample': 0.9570804287761137, 'xgb_colsample_bytree': 0.501675248936982, 'xgb_reg_alpha': 0.003423859297159864, 'xgb_reg_lambda': 0.4986323387967173, 'xgb_booster': 'dart', 'rdf_n_estimators': 20, 'rdf_max_depth': 9, 'rdf_min_samples_split': 0.9927474214720415, 'rdf_min_samples_leaf': 0.10014233250263826, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:39:11,923] Trial 117 pruned. Trial was pruned at iteration 1.
# [I 2023-08-18 16:39:13,590] Trial 118 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:18,877] Trial 119 finished with value: 0.5480211175104392 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.08223446558648342, 'cat_iterations': 716, 'cat_l2_leaf_reg': 16, 'cat_border_count': 256, 'lgb_num_leaves': 44, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.09998789117823677, 'lgb_n_estimators': 53, 'lgb_min_child_samples': 87, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.2, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010108064438864746, 'xgb_n_estimators': 703, 'xgb_min_child_weight': 2, 'xgb_subsample': 0.959486527755159, 'xgb_colsample_bytree': 0.5627664121041106, 'xgb_reg_alpha': 0.49944739289043666, 'xgb_reg_lambda': 0.49874769186695583, 'xgb_booster': 'dart', 'rdf_n_estimators': 15, 'rdf_max_depth': 2, 'rdf_min_samples_split': 0.873843754333212, 'rdf_min_samples_leaf': 0.10086549131681197, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:39:19,660] Trial 120 pruned. Trial was pruned at iteration 34.
# [I 2023-08-18 16:39:20,482] Trial 121 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:21,703] Trial 122 pruned. Trial was pruned at iteration 35.
# [I 2023-08-18 16:39:23,140] Trial 123 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:24,296] Trial 124 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:25,456] Trial 125 pruned. Trial was pruned at iteration 30.
# [I 2023-08-18 16:39:26,537] Trial 126 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:28,019] Trial 127 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:28,777] Trial 128 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:30,383] Trial 129 pruned. Trial was pruned at iteration 2.
# [I 2023-08-18 16:39:35,928] Trial 130 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:37,305] Trial 131 pruned. Trial was pruned at iteration 8.
# [I 2023-08-18 16:39:38,946] Trial 132 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:40,237] Trial 133 pruned. Trial was pruned at iteration 20.
# [I 2023-08-18 16:39:41,784] Trial 134 pruned. Trial was pruned at iteration 53.
# [I 2023-08-18 16:39:42,880] Trial 135 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:44,018] Trial 136 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:44,863] Trial 137 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:52,499] Trial 138 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:56,629] Trial 139 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:39:58,563] Trial 140 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:02,587] Trial 141 pruned. Trial was pruned at iteration 36.
# [I 2023-08-18 16:40:04,608] Trial 142 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:06,994] Trial 143 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:14,534] Trial 144 finished with value: 0.5476844331712503 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.048659225603222146, 'cat_iterations': 1508, 'cat_l2_leaf_reg': 10, 'cat_border_count': 256, 'lgb_num_leaves': 48, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09231207510889654, 'lgb_n_estimators': 63, 'lgb_min_child_samples': 82, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010192104738398241, 'xgb_n_estimators': 675, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9795863379322373, 'xgb_colsample_bytree': 0.5015710635677314, 'xgb_reg_alpha': 0.4909385940549243, 'xgb_reg_lambda': 0.4985896958428666, 'xgb_booster': 'dart', 'rdf_n_estimators': 27, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9992607992445668, 'rdf_min_samples_leaf': 0.10282493098263748, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:40:15,562] Trial 145 pruned. Trial was pruned at iteration 47.
# [I 2023-08-18 16:40:16,633] Trial 146 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:17,566] Trial 147 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:18,596] Trial 148 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:19,639] Trial 149 pruned. Trial was pruned at iteration 2.
# [I 2023-08-18 16:40:20,388] Trial 150 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:22,067] Trial 151 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:24,745] Trial 152 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:40:29,699] Trial 153 pruned. Trial was pruned at iteration 50.
# [I 2023-08-18 16:40:30,617] Trial 154 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:05,175] Trial 155 finished with value: 0.5490294810668477 and parameters: {'cat_depth': 12, 'cat_learning_rate': 0.03153465525418233, 'cat_iterations': 645, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 46, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09954511653570741, 'lgb_n_estimators': 62, 'lgb_min_child_samples': 55, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010033806972128266, 'xgb_n_estimators': 679, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9854463944381002, 'xgb_colsample_bytree': 0.5010203217771881, 'xgb_reg_alpha': 0.4918868642913702, 'xgb_reg_lambda': 0.4965091639941559, 'xgb_booster': 'dart', 'rdf_n_estimators': 29, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.995045273409461, 'rdf_min_samples_leaf': 0.1010449408976573, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:41:08,256] Trial 156 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:10,628] Trial 157 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:11,628] Trial 158 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:12,723] Trial 159 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:14,393] Trial 160 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:41:36,275] Trial 161 finished with value: 0.5491136309751734 and parameters: {'cat_depth': 11, 'cat_learning_rate': 0.029278572304127583, 'cat_iterations': 759, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 46, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09952672438901561, 'lgb_n_estimators': 62, 'lgb_min_child_samples': 53, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010403854855718711, 'xgb_n_estimators': 689, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9862917787381172, 'xgb_colsample_bytree': 0.5019237567261371, 'xgb_reg_alpha': 0.4987918463585981, 'xgb_reg_lambda': 0.4996261138041186, 'xgb_booster': 'dart', 'rdf_n_estimators': 29, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9940874359140398, 'rdf_min_samples_leaf': 0.10272937944094399, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:45:52,418] Trial 162 finished with value: 0.5543957028348897 and parameters: {'cat_depth': 15, 'cat_learning_rate': 0.03043198243730878, 'cat_iterations': 640, 'cat_l2_leaf_reg': 7, 'cat_border_count': 256, 'lgb_num_leaves': 47, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09038424373328086, 'lgb_n_estimators': 62, 'lgb_min_child_samples': 55, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010182373080597806, 'xgb_n_estimators': 679, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9815610387948691, 'xgb_colsample_bytree': 0.5032995896496353, 'xgb_reg_alpha': 0.49926649150147095, 'xgb_reg_lambda': 0.4988284255939015, 'xgb_booster': 'dart', 'rdf_n_estimators': 26, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9926999728754972, 'rdf_min_samples_leaf': 0.10039460664774798, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:48:30,643] Trial 163 finished with value: 0.5536681476009675 and parameters: {'cat_depth': 14, 'cat_learning_rate': 0.022935902193054237, 'cat_iterations': 478, 'cat_l2_leaf_reg': 6, 'cat_border_count': 256, 'lgb_num_leaves': 46, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09970477706878857, 'lgb_n_estimators': 50, 'lgb_min_child_samples': 51, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.0010009917469153745, 'xgb_n_estimators': 675, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9804861719562354, 'xgb_colsample_bytree': 0.5033205492522785, 'xgb_reg_alpha': 0.019773521892102422, 'xgb_reg_lambda': 0.49453496975102423, 'xgb_booster': 'dart', 'rdf_n_estimators': 26, 'rdf_max_depth': 10, 'rdf_min_samples_split': 0.997157080790219, 'rdf_min_samples_leaf': 0.105094985503953, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:48:39,957] Trial 164 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:48:44,341] Trial 165 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:49:26,025] Trial 166 finished with value: 0.5507370376508216 and parameters: {'cat_depth': 12, 'cat_learning_rate': 0.012831013042672283, 'cat_iterations': 1543, 'cat_l2_leaf_reg': 5, 'cat_border_count': 64, 'lgb_num_leaves': 48, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.09080846461569447, 'lgb_n_estimators': 59, 'lgb_min_child_samples': 54, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0010330102021588409, 'xgb_n_estimators': 549, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9718701640563712, 'xgb_colsample_bytree': 0.5070506678049084, 'xgb_reg_alpha': 0.4966189153431036, 'xgb_reg_lambda': 0.49950853214168695, 'xgb_booster': 'dart', 'rdf_n_estimators': 13, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.9931980411286165, 'rdf_min_samples_leaf': 0.10188477376713012, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.5393012455634046.
# [I 2023-08-18 16:49:36,295] Trial 167 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:49:37,033] Trial 168 pruned. Trial was pruned at iteration 2.
# [I 2023-08-18 16:49:38,822] Trial 169 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:49:40,660] Trial 170 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:49:47,978] Trial 171 pruned. Trial was pruned at iteration 32.
# [I 2023-08-18 16:49:53,907] Trial 172 pruned. Trial was pruned at iteration 56.
# [I 2023-08-18 16:49:54,564] Trial 173 pruned. Trial was pruned at iteration 39.
# [I 2023-08-18 16:49:56,160] Trial 174 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:49:58,637] Trial 175 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:04,218] Trial 176 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:07,890] Trial 177 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:09,645] Trial 178 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:13,606] Trial 179 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:25,889] Trial 180 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:26,381] Trial 181 pruned. Trial was pruned at iteration 32.
# [I 2023-08-18 16:50:27,309] Trial 182 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:28,164] Trial 183 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:28,643] Trial 184 pruned. Trial was pruned at iteration 9.
# [I 2023-08-18 16:50:29,988] Trial 185 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:32,056] Trial 186 pruned. Trial was pruned at iteration 33.
# [I 2023-08-18 16:50:32,862] Trial 187 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:35,333] Trial 188 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:36,226] Trial 189 pruned. Trial was pruned at iteration 25.
# [I 2023-08-18 16:50:51,547] Trial 190 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:53,944] Trial 191 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:55,982] Trial 192 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:50:57,371] Trial 193 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:51:00,879] Trial 194 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:51:02,872] Trial 195 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:51:03,863] Trial 196 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:51:09,902] Trial 197 pruned. Trial was pruned at iteration 1.
# [I 2023-08-18 16:51:10,572] Trial 198 pruned. Trial was pruned at iteration 0.
# [I 2023-08-18 16:51:19,109] Trial 199 pruned. Trial was pruned at iteration 0.
# Value:  0.5393012455634046
# Best trial: {'cat_depth': 8, 'cat_learning_rate': 0.00651224680897653, 'cat_iterations': 1821, 'cat_l2_leaf_reg': 5, 'cat_border_count': 256, 'lgb_num_leaves': 50, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.091099381427228, 'lgb_n_estimators': 89, 'lgb_min_child_samples': 54, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.001031754501018457, 'xgb_n_estimators': 235, 'xgb_min_child_weight': 5, 'xgb_subsample': 0.9871415109340169, 'xgb_colsample_bytree': 0.6444006263081316, 'xgb_reg_alpha': 0.11089498111190996, 'xgb_reg_lambda': 0.30379454797790195, 'xgb_booster': 'dart', 'rdf_n_estimators': 6, 'rdf_max_depth': 11, 'rdf_min_samples_split': 0.7610018174059954, 'rdf_min_samples_leaf': 0.10024596126396466, 'max_features': 'auto', 'rdf_bootstrap': False}
# 現在のセルまたは前のセルでコードを実行中に、カーネルがクラッシュしました。エラーの原因を特定するには、セル内のコードを確認してください。詳細については、<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a> をクリックしてください。さらなる詳細については、Jupyter [log] (command:jupyter.viewOutput) を参照してください。

# %%
# Optunaのスタディを作成
study = optuna.create_study(direction='minimize', 
                            pruner=optuna.pruners.MedianPruner(n_warmup_steps=10), 
                            sampler=optuna.samplers.TPESampler(seed=42))

# 初期のトライアルを追加
study.enqueue_trial({'cat_depth': 10, 'cat_learning_rate': 0.003270535459538743, 'cat_iterations': 1597, 'cat_l2_leaf_reg': 9, 'cat_border_count': 128, 'lgb_num_leaves': 48, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.07011111779424622, 'lgb_n_estimators': 70, 'lgb_min_child_samples': 28, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.5, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.0010770550063251198, 'xgb_n_estimators': 382, 'xgb_min_child_weight': 7, 'xgb_subsample': 0.7897564443091667, 'xgb_colsample_bytree': 0.7831846751932928, 'xgb_reg_alpha': 0.3547068459255278, 'xgb_reg_lambda': 0.4902728190181931, 'xgb_booster': 'dart', 'tab_n_d': 35, 'tab_n_a': 9, 'tab_n_steps': 8, 'tab_gamma': 1.4286132018231517, 'tab_n_independent': 1, 'tab_n_shared': 2, 'tab_lambda_sparse': 0.01624194472948726, 'tab_mask_type': 'tab_sparsemax'})

# 最適化を実行  
study.optimize(objective, 
               n_trials=100, 
               timeout=60*60*5, 
               n_jobs=5, 
               gc_after_trial=False, 
               show_progress_bar=True)  # 合計のトライアル数とタイムアウトを調整

print('  Value: ', study.best_trial.value)
print('Best trial:', study.best_trial.params)
# Out:
# [I 2023-08-18 05:53:09,134] A new study created in memory with name: no-name-d9589bd9-61aa-4d84-9388-ec00ea246a8a
#   0%|          | 0/5 [00:00<?, ?it/s]
# [I 2023-08-18 05:53:46,255] Trial 3 finished with value: 0.8800996835735749 and parameters: {'cat_depth': 7, 'cat_learning_rate': 0.00022268670782859057, 'cat_iterations': 54, 'cat_l2_leaf_reg': 17, 'cat_border_count': 128, 'lgb_num_leaves': 33, 'lgb_max_depth': 2, 'lgb_learning_rate': 0.0028751486358065824, 'lgb_n_estimators': 66, 'lgb_min_child_samples': 66, 'lgb_subsample': 1.0, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.0961147202989928, 'xgb_n_estimators': 751, 'xgb_min_child_weight': 5, 'xgb_subsample': 0.8945547305123578, 'xgb_colsample_bytree': 0.7865698117461932, 'xgb_reg_alpha': 0.10178173790712203, 'xgb_reg_lambda': 0.07089053261746464, 'xgb_booster': 'dart', 'rdf_n_estimators': 145, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.7711621421809062, 'rdf_min_samples_leaf': 0.4007885675588351, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 3 with value: 0.8800996835735749.
# [I 2023-08-18 05:57:06,144] Trial 2 finished with value: 0.7900477882736632 and parameters: {'cat_depth': 12, 'cat_learning_rate': 0.00034144493137373366, 'cat_iterations': 517, 'cat_l2_leaf_reg': 2, 'cat_border_count': 512, 'lgb_num_leaves': 25, 'lgb_max_depth': 2, 'lgb_learning_rate': 0.011942249044375486, 'lgb_n_estimators': 59, 'lgb_min_child_samples': 72, 'lgb_subsample': 1.0, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.0, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.008310838903463132, 'xgb_n_estimators': 449, 'xgb_min_child_weight': 4, 'xgb_subsample': 0.8397296270489913, 'xgb_colsample_bytree': 0.7422209191902105, 'xgb_reg_alpha': 0.1652756340680226, 'xgb_reg_lambda': 0.0712402146216855, 'xgb_booster': 'dart', 'rdf_n_estimators': 147, 'rdf_max_depth': 9, 'rdf_min_samples_split': 0.14702106905383724, 'rdf_min_samples_leaf': 0.394652347400427, 'max_features': 'sqrt', 'rdf_bootstrap': True}. Best is trial 2 with value: 0.7900477882736632.
# [I 2023-08-18 05:57:29,340] Trial 0 finished with value: 0.556925847591695 and parameters: {'cat_depth': 10, 'cat_learning_rate': 0.003270535459538743, 'cat_iterations': 1597, 'cat_l2_leaf_reg': 9, 'cat_border_count': 128, 'lgb_num_leaves': 48, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.07011111779424622, 'lgb_n_estimators': 70, 'lgb_min_child_samples': 28, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.4, 'lgb_reg_lambda': 0.5, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.0010770550063251198, 'xgb_n_estimators': 382, 'xgb_min_child_weight': 7, 'xgb_subsample': 0.7897564443091667, 'xgb_colsample_bytree': 0.7831846751932928, 'xgb_reg_alpha': 0.3547068459255278, 'xgb_reg_lambda': 0.4902728190181931, 'xgb_booster': 'dart', 'rdf_n_estimators': 137, 'rdf_max_depth': 4, 'rdf_min_samples_split': 0.8845218706959356, 'rdf_min_samples_leaf': 0.3102671705273224, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.556925847591695.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1173064/3317430658.py in <module>
#       8
#       9 # 最適化を実行
# ---> 10 study.optimize(objective,
#      11                n_trials=5,
#      12                timeout=60*60*2,
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     440                 If nested invocation of this method occurs.
#     441         """
# --> 442         _optimize(
#     443             study=self,
#     444             func=func,
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     103                             f.result()
#     104
# --> 105                     futures.add(
#     106                         executor.submit(
#     107                             _optimize_sequential,
#
# /usr/local/conda/lib/python3.9/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     634
#     635     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636         self.shutdown(wait=True)
#     637         return False
#     638
#
# /usr/local/conda/lib/python3.9/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     227         if wait:
#     228             for t in self._threads:
# --> 229                 t.join()
#     230     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/local/conda/lib/python3.9/threading.py in join(self, timeout)
#    1051
#    1052         if timeout is None:
# -> 1053             self._wait_for_tstate_lock()
#    1054         else:
#    1055             # the behavior of a negative timeout isn't documented, but
#
# /usr/local/conda/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1067         if lock is None:  # already determined that the C code is done
#    1068             assert self._is_stopped
# -> 1069         elif lock.acquire(block, timeout):
#    1070             lock.release()
#    1071             self._stop()
#
# KeyboardInterrupt:
# [I 2023-08-18 06:01:58,864] Trial 4 finished with value: 0.6044813671219804 and parameters: {'cat_depth': 15, 'cat_learning_rate': 0.006235287096638865, 'cat_iterations': 357, 'cat_l2_leaf_reg': 12, 'cat_border_count': 256, 'lgb_num_leaves': 48, 'lgb_max_depth': 3, 'lgb_learning_rate': 0.03418072523334249, 'lgb_n_estimators': 68, 'lgb_min_child_samples': 72, 'lgb_subsample': 0.9, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.0, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.0014212682667410286, 'xgb_n_estimators': 928, 'xgb_min_child_weight': 9, 'xgb_subsample': 0.5188817440636713, 'xgb_colsample_bytree': 0.8868382490778153, 'xgb_reg_alpha': 0.2759174617337231, 'xgb_reg_lambda': 0.10979927766468761, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 4, 'rdf_max_depth': 6, 'rdf_min_samples_split': 0.3671727646426943, 'rdf_min_samples_leaf': 0.2352770083901374, 'max_features': 'auto', 'rdf_bootstrap': False}. Best is trial 0 with value: 0.556925847591695.

# %%
path = 'ave1'

# 最適なトライアルのハイパーパラメータを取得
best_params = study.best_trial.params

# モデルを保存するディレクトリのパスを設定
directory_path = f'../../model/{path}/'
# 指定したディレクトリが存在しない場合、ディレクトリを作成
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    
# CatBoostモデルのハイパーパラメータを設定して保存
cat_params = {
    'depth': best_params['cat_depth'],
    'learning_rate': best_params['cat_learning_rate'],
    'iterations': best_params['cat_iterations'],
    'l2_leaf_reg': best_params['cat_l2_leaf_reg'],
    'border_count': best_params['cat_border_count'],
    'thread_count': 4,
    'verbose': False
}
cat_best_model = CatBoostRegressor(**cat_params)
cat_best_model.fit(X, y, verbose=False)
# モデルを指定したパスに保存
cat_best_model.save_model(f'../../model/{path}/catboost.cbm')

# LightGBMモデルのハイパーパラメータを設定して保存
lgb_params = {
    'num_leaves': best_params['lgb_num_leaves'],
    'max_depth': best_params['lgb_max_depth'],
    'learning_rate': best_params['lgb_learning_rate'],
    'n_estimators': best_params['lgb_n_estimators'],
    'min_child_samples': best_params['lgb_min_child_samples'],
    'subsample': best_params['lgb_subsample'],
    'colsample_bytree': best_params['lgb_colsample_bytree'],
    'reg_alpha': best_params['lgb_reg_alpha'],
    'reg_lambda': best_params['lgb_reg_lambda'],
    'force_col_wise': True,
    'verbose': -1
}
lgb_best_model = LGBMRegressor(**lgb_params)
lgb_best_model.fit(X, y)
# モデルを指定したパスに保存
lgb_best_model.booster_.save_model(f'../../model/{path}/lightGBM.bin')

# XGBoostモデルのハイパーパラメータを設定して保存
xgb_params = {
    'max_depth': best_params['xgb_max_depth'],
    'learning_rate': best_params['xgb_learning_rate'],
    'n_estimators': best_params['xgb_n_estimators'],
    'min_child_weight': best_params['xgb_min_child_weight'],
    'subsample': best_params['xgb_subsample'],
    'colsample_bytree': best_params['xgb_colsample_bytree'],
    'reg_alpha': best_params['xgb_reg_alpha'],
    'reg_lambda': best_params['xgb_reg_lambda'],
    'verbosity': 0,
    'objective': 'reg:squarederror',
    'booster': best_params['xgb_booster'],
    'tree_method': 'hist',
    'seed': 42
}
dtrain = xgb.DMatrix(X, label=y)
xgb_best_model = xgb.train(xgb_params, dtrain, verbose_eval=False)
# モデルを指定したパスに保存
xgb_best_model.save_model(f'../../model/{path}/XGBoost.xgb')

# TabNetモデルのハイパーパラメータを設定して保存
tab_params = {
    'n_d': best_params['tab_n_d'],
    'n_a': best_params['tab_n_a'],
    'n_steps': best_params['tab_n_steps'],
    'gamma': best_params['tab_gamma'],
    'n_independent': best_params['tab_n_independent'],
    'n_shared': best_params['tab_n_shared'],
    'lambda_sparse': best_params['tab_lambda_sparse'],
    'optimizer_fn': torch.optim.Adam,
    'mask_type': best_params['tab_mask_type'],
    'scheduler_params': {"step_size":10, "gamma":0.9},
    'scheduler_fn': torch.optim.lr_scheduler.StepLR,
    'verbose': 0
}
tab_best_model = TabNetRegressor(**tab_params)
tab_best_model.fit(X.values, y.values.reshape(-1, 1), patience=10, batch_size=256, virtual_batch_size=128, max_epochs=1000, num_workers=0, drop_last=False)
# モデルを指定したパスに保存
torch.save(f'../model/{path}/tabnet')
