# %%
# 基本的なライブラリ
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import random
import os

# モデル関連
import lightgbm as lgb
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
import xgboost as xgb

# モデル評価・前処理関連
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve, cross_val_score, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# ハイパーパラメータ最適化関連
import optuna
from optuna.integration import LightGBMPruningCallback, XGBoostPruningCallback
import optuna.visualization as vis

# その他のユーティリティ
import shap
import joblib

# 乱数のシードを固定
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# 警告を無視
warnings.filterwarnings("ignore")

# %%
# データの読み込み
all_data = pd.read_csv('../../data_processed/all_data1.csv')

train_data = all_data[0:27532]
X = train_data.drop(['price'], axis=1)
y = train_data['price']

# データの分割
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
def catboost_params(trial):
    return {
        'depth': trial.suggest_int('cat_depth', 4, 16),
        'learning_rate': trial.suggest_loguniform('cat_learning_rate', 0.00001, 0.1),
        'iterations': trial.suggest_int('cat_iterations', 50, 2000),
        'l2_leaf_reg': trial.suggest_int('cat_l2_leaf_reg', 1, 20),
        'border_count': trial.suggest_categorical('cat_border_count', [32, 64, 128, 256, 512]),
        'thread_count': 4
    }

def lightgbm_params(trial):
    return {
        'num_leaves': trial.suggest_int('lgb_num_leaves', 10, 50),
        'max_depth': trial.suggest_int('lgb_max_depth', 2, 7),
        'learning_rate': trial.suggest_float('lgb_learning_rate', 0.001, 0.1, log=True),
        'n_estimators': trial.suggest_int('lgb_n_estimators', 50, 100),
        'min_child_samples': trial.suggest_int('lgb_min_child_samples', 20, 100),
        'subsample': trial.suggest_float('lgb_subsample', 0.5, 1.0, step=0.1),
        'colsample_bytree': trial.suggest_float('lgb_colsample_bytree', 0.4, 1.0, step=0.1),
        'reg_alpha': trial.suggest_float('lgb_reg_alpha', 0.0, 0.5, step=0.1),
        'reg_lambda': trial.suggest_float('lgb_reg_lambda', 0.0, 0.5, step=0.1),
        'force_col_wise': True,  
        'verbose': -1  # 出力を無効にする
    }

def xgboost_params(trial):
    return {
        'max_depth': trial.suggest_int('xgb_max_depth', 3, 9),
        'learning_rate': trial.suggest_loguniform('xgb_learning_rate', 0.001, 0.1),
        'n_estimators': trial.suggest_int('xgb_n_estimators', 50, 1000),
        'min_child_weight': trial.suggest_int('xgb_min_child_weight', 1, 10),
        'subsample': trial.suggest_float('xgb_subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('xgb_colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('xgb_reg_alpha', 0.0, 0.5),
        'reg_lambda': trial.suggest_float('xgb_reg_lambda', 0.0, 0.5),
        'verbosity': 0,  # 出力を無効にする
        'objective': 'reg:squarederror',
        'booster': trial.suggest_categorical('xgb_booster', ['gbtree', 'gblinear', 'dart']),
        'tree_method': 'hist',
        'seed': 42
    }

# def tabnet_params(trial):
#     return {
#         'n_d': trial.suggest_int('tab_n_d', 8, 64),
#         'n_a': trial.suggest_int('tab_n_a', 8, 64),
#         'n_steps': trial.suggest_int('tab_n_steps', 3, 10),
#         'gamma': trial.suggest_float('tab_gamma', 1.0, 2.0),
#         'n_independent': trial.suggest_int('tab_n_independent', 1, 5),
#         'n_shared': trial.suggest_int('tab_n_shared', 1, 5),
#         'lambda_sparse': trial.suggest_float('tab_lambda_sparse', 1e-5, 1e-1, log=True),
#         'optimizer_fn': torch.optim.Adam,
#         'scheduler_params': {"step_size":10, "gamma":0.9},
#         'scheduler_fn': torch.optim.lr_scheduler.StepLR,
#         'verbose': 0
#     }

def randomforest_params(trial):
    return  {
            'n_estimators': trial.suggest_int('rdf_n_estimators', 2, 150),
            'max_depth': trial.suggest_int('rdf_max_depth', 1, 32, log=True),
            'min_samples_split': trial.suggest_float('rdf_min_samples_split', 0.1, 1),
            'min_samples_leaf': trial.suggest_float('rdf_min_samples_leaf', 0.1, 0.5),                
            'max_features': trial.suggest_categorical('max_features', ['auto', 'sqrt', 'log2']),
            'bootstrap': trial.suggest_categorical('rdf_bootstrap', [True, False]),
            'random_state': 42
    }
    
def gbm_params(trial):
    return {
        'n_estimators': trial.suggest_int('gbm_n_estimators', 50, 1000),
        'max_depth': trial.suggest_int('gbm_max_depth', 3, 9),
        'learning_rate': trial.suggest_loguniform('gbm_learning_rate', 0.001, 0.1),
        'min_samples_split': trial.suggest_int('gbm_min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('gbm_min_samples_leaf', 1, 10),
        'subsample': trial.suggest_float('gbm_subsample', 0.5, 1.0),
        'max_features': trial.suggest_categorical('gbm_max_features', ['auto', 'sqrt', 'log2']),
        'random_state': 42
    }
    
def ridge_params(trial):
    return {
        'alpha': trial.suggest_float('ridge_alpha', 0.001, 10.0, log=True),
        'fit_intercept': trial.suggest_categorical('ridge_fit_intercept', [True, False]),
        'normalize': trial.suggest_categorical('ridge_normalize', [True, False]),
        'random_state': 42
    }
    
def lasso_params(trial):
    return {
        'alpha': trial.suggest_float('lasso_alpha', 0.001, 10.0, log=True),
        'fit_intercept': trial.suggest_categorical('lasso_fit_intercept', [True, False]),
        'normalize': trial.suggest_categorical('lasso_normalize', [True, False]),
        'random_state': 42
    }

    
def objective(trial):
    # 交差検証の設定
    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    mape_scores = []

    for train_idx, val_idx in kf.split(X, y):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        # CatBoost
        cat_model = CatBoostRegressor(**catboost_params(trial), random_seed=42, verbose=0)
        cat_model.fit(X_train, y_train, 
                      eval_set=[(X_val, y_val)], 
                      early_stopping_rounds=10, 
                      cat_features=[])
        
        # LightGBM
        lgb_model = LGBMRegressor(**lightgbm_params(trial), random_state=42)
        lgb_model.fit(X_train, y_train, eval_metric='mape', 
                      eval_set=[(X_val, y_val)],
                      callbacks=[LightGBMPruningCallback(trial, 'l2')]) # 出力を無効にする
        
        # XGBoost
        dval = xgb.DMatrix(X_val, label=y_val)
        xgb_model = xgb.train(xgboost_params(trial), dval, evals=[(dval, 'eval')], 
                              early_stopping_rounds=10, 
                              callbacks=[XGBoostPruningCallback(trial, 'eval-rmse')], verbose_eval=False)
        
        # # tannet
        # tab_model = TabNetRegressor(**tabnet_params(trial))
        # tab_model.fit(X_train.values, y_train.values.reshape(-1, 1), 
        #               eval_set=[(X_val.values, y_val.values.reshape(-1, 1))])
        
        # RandomForest
        rdf_model = RandomForestRegressor(**randomforest_params(trial))
        rdf_model.fit(X_train, y_train)
        
        # GBM
        gbm_model = GradientBoostingRegressor(**gbm_params(trial))
        gbm_model.fit(X_train, y_train)
        
        # Ridge Regression
        ridge_model = Ridge(**ridge_params(trial))
        ridge_model.fit(X_train, y_train)
        
        # Lasso Regression
        lasso_model = Lasso(**lasso_params(trial))
        lasso_model.fit(X_train, y_train)
        
        # 各モデルの予測を取得
        cat_preds = cat_model.predict(X_val)
        lgb_preds = lgb_model.predict(X_val)
        dval = xgb.DMatrix(X_val)
        xgb_preds = xgb_model.predict(dval)
        # tab_preds = tab_model.predict(X_val.values)
        gbm_preds = gbm_model.predict(X_val)
        rdf_preds = rdf_model.predict(X_val)
        ridge_preds = ridge_model.predict(X_val)
        lasso_preds = lasso_model.predict(X_val)
        
        # 6つのモデルの予測の重みのハイパーパラメータを設定
        cat_weight = trial.suggest_float('cat_weight', 0, 0.5)
        lgb_weight = trial.suggest_float('lgb_weight', 0, 1 - cat_weight)
        xgb_weight = trial.suggest_float('xgb_weight', 0, 1 - cat_weight - lgb_weight)
        rdf_weight = trial.suggest_float('rdf_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight)
        ridge_weight = trial.suggest_float('ridge_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight)
        lasso_weight = trial.suggest_float('lasso_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight - ridge_weight )
        gbm_weight = trial.suggest_float('gbm_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight - ridge_weight - lasso_weight)

        # 6つのモデルの予測を加重平均して最終的な予測を得る
        final_preds = (cat_preds * cat_weight + lgb_preds * lgb_weight + xgb_preds * xgb_weight + rdf_preds * rdf_weight + ridge_preds * ridge_weight + lasso_preds * lasso_weight + gbm_preds * gbm_weight) / (cat_weight + lgb_weight + xgb_weight + rdf_weight + ridge_weight + lasso_weight + gbm_weight)

    
        mape = mean_absolute_percentage_error(y_val, final_preds)
        mape_scores.append(mape)
    
    return sum(mape_scores) / n_splits

# %%
# Optunaのスタディを作成
study = optuna.create_study(direction='minimize', 
                            pruner=optuna.pruners.MedianPruner(n_warmup_steps=30), 
                            sampler=optuna.samplers.TPESampler(seed=SEED))

# 初期のトライアルを追加
study.enqueue_trial({'cat_depth': 4, 'cat_learning_rate': 0.0030494571483717183, 'cat_iterations': 1241, 'cat_l2_leaf_reg': 18, 'cat_border_count': 128, 'lgb_num_leaves': 39, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.001543892983209765, 'lgb_n_estimators': 87, 'lgb_min_child_samples': 71, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.4, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.014602575561312671, 'xgb_n_estimators': 941, 'xgb_min_child_weight': 8, 'xgb_subsample': 0.5113888436769296, 'xgb_colsample_bytree': 0.770853966308576, 'xgb_reg_alpha': 0.3197429291354004, 'xgb_reg_lambda': 0.13183424517556913, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 26, 'rdf_max_depth': 3, 'rdf_min_samples_split': 0.21320458702870007, 'rdf_min_samples_leaf': 0.3485339409136515, 'max_features': 'auto', 'rdf_bootstrap': True, 'gbm_n_estimators': 618, 'gbm_max_depth': 6, 'gbm_learning_rate': 0.013105330317351494, 'gbm_min_samples_split': 4, 'gbm_min_samples_leaf': 3, 'gbm_subsample': 0.7884121303425939, 'gbm_max_features': 'log2', 'ridge_alpha': 0.07250219633049332, 'ridge_fit_intercept': True, 'ridge_normalize': False, 'lasso_alpha': 3.019733595109704, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.4967316834305898, 'lgb_weight': 0.025093775479547248, 'xgb_weight': 0.32711741508350634, 'rdf_weight': 0.12708918323428908, 'ridge_weight': 0.01612093140957428, 'lasso_weight': 0.005720489423377935, 'gbm_weight': 0.0011549902928533762})

# 最適化を実行  
study.optimize(objective, 
               n_trials=500, 
               timeout=None, 
               n_jobs=4, 
               gc_after_trial=False, 
               show_progress_bar=True)  # 合計のトライアル数とタイムアウトを調整
# Out:
# [I 2023-08-19 13:57:14,364] A new study created in memory with name: no-name-0e413594-271a-4d16-8811-020973490755
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2023-08-19 13:58:16,034] Trial 2 finished with value: 0.686991672850312 and parameters: {'cat_depth': 4, 'cat_learning_rate': 0.00595722417689089, 'cat_iterations': 743, 'cat_l2_leaf_reg': 2, 'cat_border_count': 256, 'lgb_num_leaves': 47, 'lgb_max_depth': 3, 'lgb_learning_rate': 0.007452027174286386, 'lgb_n_estimators': 83, 'lgb_min_child_samples': 77, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.5, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.07755817907135486, 'xgb_n_estimators': 313, 'xgb_min_child_weight': 8, 'xgb_subsample': 0.6153677035780876, 'xgb_colsample_bytree': 0.8280815021084594, 'xgb_reg_alpha': 0.3307294910194956, 'xgb_reg_lambda': 0.49663918187468525, 'xgb_booster': 'dart', 'rdf_n_estimators': 103, 'rdf_max_depth': 21, 'rdf_min_samples_split': 0.455827205911816, 'rdf_min_samples_leaf': 0.15236574669452524, 'max_features': 'log2', 'rdf_bootstrap': True, 'gbm_n_estimators': 311, 'gbm_max_depth': 7, 'gbm_learning_rate': 0.0028189646117676237, 'gbm_min_samples_split': 6, 'gbm_min_samples_leaf': 9, 'gbm_subsample': 0.9209662274444128, 'gbm_max_features': 'log2', 'ridge_alpha': 4.076172659217747, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.03644244515923108, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.3488649701703772, 'lgb_weight': 0.3886732569505778, 'xgb_weight': 0.24309788826352974, 'rdf_weight': 0.01661428594482433, 'ridge_weight': 0.0024336530042279353, 'lasso_weight': 0.00026686696541275114, 'gbm_weight': 4.3380883078860126e-05}. Best is trial 2 with value: 0.686991672850312.
# [I 2023-08-19 13:58:46,326] Trial 0 finished with value: 0.5449070545790077 and parameters: {'cat_depth': 4, 'cat_learning_rate': 0.0030494571483717183, 'cat_iterations': 1241, 'cat_l2_leaf_reg': 18, 'cat_border_count': 128, 'lgb_num_leaves': 39, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.001543892983209765, 'lgb_n_estimators': 87, 'lgb_min_child_samples': 71, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.4, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.014602575561312671, 'xgb_n_estimators': 941, 'xgb_min_child_weight': 8, 'xgb_subsample': 0.5113888436769296, 'xgb_colsample_bytree': 0.770853966308576, 'xgb_reg_alpha': 0.3197429291354004, 'xgb_reg_lambda': 0.13183424517556913, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 26, 'rdf_max_depth': 3, 'rdf_min_samples_split': 0.21320458702870007, 'rdf_min_samples_leaf': 0.3485339409136515, 'max_features': 'auto', 'rdf_bootstrap': True, 'gbm_n_estimators': 618, 'gbm_max_depth': 6, 'gbm_learning_rate': 0.013105330317351494, 'gbm_min_samples_split': 4, 'gbm_min_samples_leaf': 3, 'gbm_subsample': 0.7884121303425939, 'gbm_max_features': 'log2', 'ridge_alpha': 0.07250219633049332, 'ridge_fit_intercept': True, 'ridge_normalize': False, 'lasso_alpha': 3.019733595109704, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.4967316834305898, 'lgb_weight': 0.025093775479547248, 'xgb_weight': 0.32711741508350634, 'rdf_weight': 0.12708918323428908, 'ridge_weight': 0.01612093140957428, 'lasso_weight': 0.005720489423377935, 'gbm_weight': 0.0011549902928533762}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 13:58:50,511] Trial 1 finished with value: 0.624029904426098 and parameters: {'cat_depth': 4, 'cat_learning_rate': 0.02467034248315918, 'cat_iterations': 717, 'cat_l2_leaf_reg': 9, 'cat_border_count': 512, 'lgb_num_leaves': 31, 'lgb_max_depth': 2, 'lgb_learning_rate': 0.0014019006722577761, 'lgb_n_estimators': 83, 'lgb_min_child_samples': 90, 'lgb_subsample': 1.0, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.01648317687116282, 'xgb_n_estimators': 980, 'xgb_min_child_weight': 9, 'xgb_subsample': 0.9412294565179715, 'xgb_colsample_bytree': 0.8953730107832694, 'xgb_reg_alpha': 0.4047733172438362, 'xgb_reg_lambda': 0.36940735734467195, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 93, 'rdf_max_depth': 25, 'rdf_min_samples_split': 0.8090092858992207, 'rdf_min_samples_leaf': 0.3540357148313883, 'max_features': 'log2', 'rdf_bootstrap': False, 'gbm_n_estimators': 942, 'gbm_max_depth': 4, 'gbm_learning_rate': 0.021034306617195443, 'gbm_min_samples_split': 9, 'gbm_min_samples_leaf': 4, 'gbm_subsample': 0.8465187887325587, 'gbm_max_features': 'sqrt', 'ridge_alpha': 0.007102854535019271, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.23789423947842847, 'lasso_fit_intercept': True, 'lasso_normalize': False, 'cat_weight': 0.26369141320070016, 'lgb_weight': 0.3075432724859686, 'xgb_weight': 0.3072340141596222, 'rdf_weight': 0.09611158943593533, 'ridge_weight': 0.020030086721151245, 'lasso_weight': 0.0013115274393460333, 'gbm_weight': 0.0003129443219047551}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 13:59:44,763] Trial 4 finished with value: 0.7266171336745376 and parameters: {'cat_depth': 8, 'cat_learning_rate': 0.0006889558635588431, 'cat_iterations': 1428, 'cat_l2_leaf_reg': 20, 'cat_border_count': 512, 'lgb_num_leaves': 35, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.0133515277605336, 'lgb_n_estimators': 96, 'lgb_min_child_samples': 79, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.003265613452187429, 'xgb_n_estimators': 553, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.7173271359558123, 'xgb_colsample_bytree': 0.8880516736780062, 'xgb_reg_alpha': 0.3134001041869493, 'xgb_reg_lambda': 0.27281983442884694, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 18, 'rdf_max_depth': 4, 'rdf_min_samples_split': 0.7001841925738228, 'rdf_min_samples_leaf': 0.48089294328357124, 'max_features': 'auto', 'rdf_bootstrap': True, 'gbm_n_estimators': 52, 'gbm_max_depth': 7, 'gbm_learning_rate': 0.07205931278969811, 'gbm_min_samples_split': 7, 'gbm_min_samples_leaf': 6, 'gbm_subsample': 0.6499746408546379, 'gbm_max_features': 'log2', 'ridge_alpha': 1.1613246439457927, 'ridge_fit_intercept': False, 'ridge_normalize': False, 'lasso_alpha': 0.00376099178335674, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.18245253594257033, 'lgb_weight': 0.6780169730403091, 'xgb_weight': 0.11897477359989195, 'rdf_weight': 0.012409572211386536, 'ridge_weight': 0.0009359324305500581, 'lasso_weight': 0.00021657070654027843, 'gbm_weight': 0.006234390723260471}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:01:43,996] Trial 6 finished with value: 0.8831861262686722 and parameters: {'cat_depth': 9, 'cat_learning_rate': 0.002896316907236269, 'cat_iterations': 1058, 'cat_l2_leaf_reg': 1, 'cat_border_count': 128, 'lgb_num_leaves': 48, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.0065303896352587616, 'lgb_n_estimators': 82, 'lgb_min_child_samples': 90, 'lgb_subsample': 0.7, 'lgb_colsample_bytree': 1.0, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.002965608758902522, 'xgb_n_estimators': 799, 'xgb_min_child_weight': 10, 'xgb_subsample': 0.6984874323592449, 'xgb_colsample_bytree': 0.9760092641257344, 'xgb_reg_alpha': 0.11542668027955633, 'xgb_reg_lambda': 0.22032493815452037, 'xgb_booster': 'dart', 'rdf_n_estimators': 70, 'rdf_max_depth': 31, 'rdf_min_samples_split': 0.653164886382223, 'rdf_min_samples_leaf': 0.335596932854243, 'max_features': 'sqrt', 'rdf_bootstrap': False, 'gbm_n_estimators': 281, 'gbm_max_depth': 6, 'gbm_learning_rate': 0.05969000300339858, 'gbm_min_samples_split': 9, 'gbm_min_samples_leaf': 9, 'gbm_subsample': 0.8253091312388113, 'gbm_max_features': 'sqrt', 'ridge_alpha': 0.1619599512839278, 'ridge_fit_intercept': False, 'ridge_normalize': False, 'lasso_alpha': 0.0014551582300671977, 'lasso_fit_intercept': False, 'lasso_normalize': True, 'cat_weight': 0.09673012906260503, 'lgb_weight': 0.7675646398467948, 'xgb_weight': 0.015632194927284317, 'rdf_weight': 0.03526315948019736, 'ridge_weight': 0.0016956918656216827, 'lasso_weight': 0.06662916013230685, 'gbm_weight': 0.002409130499571007}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:02:03,960] Trial 7 pruned. Trial was pruned at iteration 0.
# [I 2023-08-19 14:06:06,021] Trial 5 finished with value: 0.8642480103376547 and parameters: {'cat_depth': 13, 'cat_learning_rate': 1.9976776046032936e-05, 'cat_iterations': 203, 'cat_l2_leaf_reg': 10, 'cat_border_count': 512, 'lgb_num_leaves': 20, 'lgb_max_depth': 2, 'lgb_learning_rate': 0.06247745841741356, 'lgb_n_estimators': 94, 'lgb_min_child_samples': 92, 'lgb_subsample': 0.6, 'lgb_colsample_bytree': 0.4, 'lgb_reg_alpha': 0.0, 'lgb_reg_lambda': 0.30000000000000004, 'xgb_max_depth': 9, 'xgb_learning_rate': 0.061165540146089825, 'xgb_n_estimators': 863, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.9947678405676369, 'xgb_colsample_bytree': 0.9288100207978223, 'xgb_reg_alpha': 0.1877953091558629, 'xgb_reg_lambda': 0.18327584696907445, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 43, 'rdf_max_depth': 11, 'rdf_min_samples_split': 0.4638753751342911, 'rdf_min_samples_leaf': 0.35344741117408096, 'max_features': 'log2', 'rdf_bootstrap': True, 'gbm_n_estimators': 601, 'gbm_max_depth': 6, 'gbm_learning_rate': 0.0013704262414290355, 'gbm_min_samples_split': 3, 'gbm_min_samples_leaf': 10, 'gbm_subsample': 0.76552072026697, 'gbm_max_features': 'log2', 'ridge_alpha': 0.12228642238592102, 'ridge_fit_intercept': True, 'ridge_normalize': True, 'lasso_alpha': 5.199723728543201, 'lasso_fit_intercept': False, 'lasso_normalize': False, 'cat_weight': 0.43113309382782067, 'lgb_weight': 0.5289759962471297, 'xgb_weight': 0.030927174891439004, 'rdf_weight': 0.0079884263317615, 'ridge_weight': 0.00017119783886060513, 'lasso_weight': 0.0006669289823098239, 'gbm_weight': 7.2866975057772e-05}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:10:28,741] Trial 10 finished with value: 0.9996193770020314 and parameters: {'cat_depth': 11, 'cat_learning_rate': 0.0008327378925041018, 'cat_iterations': 81, 'cat_l2_leaf_reg': 10, 'cat_border_count': 64, 'lgb_num_leaves': 22, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.019764050744817827, 'lgb_n_estimators': 68, 'lgb_min_child_samples': 63, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.8, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.0, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.05388804228538403, 'xgb_n_estimators': 96, 'xgb_min_child_weight': 7, 'xgb_subsample': 0.9676594400328222, 'xgb_colsample_bytree': 0.5680606263601871, 'xgb_reg_alpha': 0.19843844344958494, 'xgb_reg_lambda': 0.3980114710809481, 'xgb_booster': 'gblinear', 'rdf_n_estimators': 43, 'rdf_max_depth': 1, 'rdf_min_samples_split': 0.4696092976690166, 'rdf_min_samples_leaf': 0.22054597500769582, 'max_features': 'log2', 'rdf_bootstrap': True, 'gbm_n_estimators': 547, 'gbm_max_depth': 9, 'gbm_learning_rate': 0.00456755919882971, 'gbm_min_samples_split': 6, 'gbm_min_samples_leaf': 1, 'gbm_subsample': 0.8543001409490709, 'gbm_max_features': 'log2', 'ridge_alpha': 0.06738573573357405, 'ridge_fit_intercept': True, 'ridge_normalize': False, 'lasso_alpha': 0.6872352484772624, 'lasso_fit_intercept': False, 'lasso_normalize': False, 'cat_weight': 0.23962175338130526, 'lgb_weight': 0.10026966171598083, 'xgb_weight': 0.2565234043585565, 'rdf_weight': 0.3460505609682793, 'ridge_weight': 0.029848207620034962, 'lasso_weight': 0.01942711640983937, 'gbm_weight': 0.007926195646304283}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:10:45,552] Trial 11 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:12:56,098] Trial 9 pruned. Trial was pruned at iteration 64.
# [I 2023-08-19 14:12:58,929] Trial 13 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:06,140] Trial 14 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:13,092] Trial 12 finished with value: 0.7609488494068372 and parameters: {'cat_depth': 10, 'cat_learning_rate': 0.0001474416450596257, 'cat_iterations': 806, 'cat_l2_leaf_reg': 1, 'cat_border_count': 32, 'lgb_num_leaves': 20, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.027185293211410673, 'lgb_n_estimators': 71, 'lgb_min_child_samples': 51, 'lgb_subsample': 0.9, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.006025083491538731, 'xgb_n_estimators': 316, 'xgb_min_child_weight': 1, 'xgb_subsample': 0.6753012121384918, 'xgb_colsample_bytree': 0.8943926255781547, 'xgb_reg_alpha': 0.3315455307946181, 'xgb_reg_lambda': 0.006597694409993415, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 41, 'rdf_max_depth': 30, 'rdf_min_samples_split': 0.15624546827661276, 'rdf_min_samples_leaf': 0.22263710254313718, 'max_features': 'sqrt', 'rdf_bootstrap': False, 'gbm_n_estimators': 164, 'gbm_max_depth': 4, 'gbm_learning_rate': 0.01215187185986528, 'gbm_min_samples_split': 6, 'gbm_min_samples_leaf': 4, 'gbm_subsample': 0.5892020377462903, 'gbm_max_features': 'log2', 'ridge_alpha': 1.5964187953828928, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.03113623559314715, 'lasso_fit_intercept': False, 'lasso_normalize': True, 'cat_weight': 0.2991931250731097, 'lgb_weight': 0.31782373007547826, 'xgb_weight': 0.10729798234662628, 'rdf_weight': 0.04356616756022388, 'ridge_weight': 0.002172225583343969, 'lasso_weight': 0.09450052292311027, 'gbm_weight': 0.12936888170022656}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:13:13,286] Trial 15 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:15,054] Trial 17 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:15,759] Trial 16 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:19,632] Trial 18 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:26,033] Trial 20 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:13:27,936] Trial 19 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:21:28,380] Trial 3 finished with value: 0.9365528235933087 and parameters: {'cat_depth': 16, 'cat_learning_rate': 2.528329127645921e-05, 'cat_iterations': 119, 'cat_l2_leaf_reg': 2, 'cat_border_count': 512, 'lgb_num_leaves': 19, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.02373108122483553, 'lgb_n_estimators': 89, 'lgb_min_child_samples': 67, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.2, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.022225654132979118, 'xgb_n_estimators': 619, 'xgb_min_child_weight': 3, 'xgb_subsample': 0.9791780187060912, 'xgb_colsample_bytree': 0.6535725853736943, 'xgb_reg_alpha': 0.3685761571244745, 'xgb_reg_lambda': 0.1708497979404826, 'xgb_booster': 'gblinear', 'rdf_n_estimators': 32, 'rdf_max_depth': 5, 'rdf_min_samples_split': 0.3912992417926069, 'rdf_min_samples_leaf': 0.23498162819117582, 'max_features': 'auto', 'rdf_bootstrap': False, 'gbm_n_estimators': 636, 'gbm_max_depth': 4, 'gbm_learning_rate': 0.0020192513731252756, 'gbm_min_samples_split': 7, 'gbm_min_samples_leaf': 3, 'gbm_subsample': 0.9609665041522485, 'gbm_max_features': 'auto', 'ridge_alpha': 0.07194107475172772, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.9943373507643831, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.43217453433166186, 'lgb_weight': 0.2843849684162897, 'xgb_weight': 0.14156137899845253, 'rdf_weight': 0.022450390235701678, 'ridge_weight': 0.05735059488522535, 'lasso_weight': 0.05760906533503769, 'gbm_weight': 0.003927713249640557}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:24:26,576] Trial 21 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:24:36,781] Trial 24 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:24:42,123] Trial 25 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:24:47,020] Trial 26 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:24:56,969] Trial 27 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:04,094] Trial 23 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:08,370] Trial 29 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:09,936] Trial 28 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:20,958] Trial 30 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:21,964] Trial 31 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:31,363] Trial 33 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:35,721] Trial 32 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:25:45,532] Trial 34 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:26:10,590] Trial 35 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:26:25,516] Trial 36 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:26:45,314] Trial 38 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:26:54,424] Trial 39 pruned. Trial was pruned at iteration 45.
# [I 2023-08-19 14:27:39,473] Trial 37 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:30:36,179] Trial 22 pruned. Trial was pruned at iteration 30.
# [I 2023-08-19 14:31:07,378] Trial 42 pruned. Trial was pruned at iteration 87.
# [I 2023-08-19 14:31:08,359] Trial 40 pruned. Trial was pruned at iteration 30.
# [W 2023-08-19 14:31:24,117] Trial 44 failed with parameters: {'cat_depth': 10, 'cat_learning_rate': 0.00016132610945239655, 'cat_iterations': 784, 'cat_l2_leaf_reg': 2, 'cat_border_count': 32, 'lgb_num_leaves': 18, 'lgb_max_depth': 6, 'lgb_learning_rate': 0.03093848204341762, 'lgb_n_estimators': 72, 'lgb_min_child_samples': 47, 'lgb_subsample': 0.9, 'lgb_colsample_bytree': 0.7000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.2, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.006995558217054526, 'xgb_n_estimators': 996, 'xgb_min_child_weight': 8, 'xgb_subsample': 0.6790541889991977, 'xgb_colsample_bytree': 0.8593782825041908, 'xgb_reg_alpha': 0.3566415554742993, 'xgb_reg_lambda': 0.48967075510095737, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 4, 'rdf_max_depth': 32, 'rdf_min_samples_split': 0.1632765780708374, 'rdf_min_samples_leaf': 0.46059053097805347, 'max_features': 'sqrt', 'rdf_bootstrap': True, 'gbm_n_estimators': 66, 'gbm_max_depth': 7, 'gbm_learning_rate': 0.016964959999626803, 'gbm_min_samples_split': 5, 'gbm_min_samples_leaf': 5, 'gbm_subsample': 0.5696525726705465, 'gbm_max_features': 'log2', 'ridge_alpha': 4.057215271169473, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.025522649896177193, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.31807312528093257, 'lgb_weight': 0.3945231885904261, 'xgb_weight': 0.2867691654775748, 'rdf_weight': 0.15956365454258592} because of the following error: ValueError('The `low` value must be smaller than or equal to the `high` value (low=0, high=-0.15892913389151941).').
# Traceback (most recent call last):
#   File "/usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_58854/3876760729.py", line 165, in objective
#     ridge_weight = trial.suggest_float('ridge_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight)
#   File "/usr/local/conda/lib/python3.9/site-packages/optuna/trial/_trial.py", line 160, in suggest_float
#     distribution = FloatDistribution(low, high, log=log, step=step)
#   File "/usr/local/conda/lib/python3.9/site-packages/optuna/distributions.py", line 142, in __init__
#     raise ValueError(
# ValueError: The `low` value must be smaller than or equal to the `high` value (low=0, high=-0.15892913389151941).
# [W 2023-08-19 14:31:24,138] Trial 44 failed with value None.
# [I 2023-08-19 14:31:41,031] Trial 41 finished with value: 0.6426954900900388 and parameters: {'cat_depth': 5, 'cat_learning_rate': 0.0006730911637031194, 'cat_iterations': 532, 'cat_l2_leaf_reg': 15, 'cat_border_count': 32, 'lgb_num_leaves': 43, 'lgb_max_depth': 4, 'lgb_learning_rate': 0.03386395367918594, 'lgb_n_estimators': 93, 'lgb_min_child_samples': 64, 'lgb_subsample': 0.5, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.1, 'lgb_reg_lambda': 0.1, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.010653323608453542, 'xgb_n_estimators': 988, 'xgb_min_child_weight': 7, 'xgb_subsample': 0.5576586829365715, 'xgb_colsample_bytree': 0.8156084905585096, 'xgb_reg_alpha': 0.43898012360670535, 'xgb_reg_lambda': 0.4945928163498138, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 2, 'rdf_max_depth': 4, 'rdf_min_samples_split': 0.8321056268598048, 'rdf_min_samples_leaf': 0.48136350808787903, 'max_features': 'log2', 'rdf_bootstrap': True, 'gbm_n_estimators': 974, 'gbm_max_depth': 8, 'gbm_learning_rate': 0.022219094853575223, 'gbm_min_samples_split': 4, 'gbm_min_samples_leaf': 6, 'gbm_subsample': 0.9027633662240699, 'gbm_max_features': 'sqrt', 'ridge_alpha': 0.0055893959143501655, 'ridge_fit_intercept': False, 'ridge_normalize': False, 'lasso_alpha': 0.038116141430900606, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.4866593525630248, 'lgb_weight': 0.00573274047554025, 'xgb_weight': 0.3464144053208979, 'rdf_weight': 0.08660144647801218, 'ridge_weight': 0.018173548720857257, 'lasso_weight': 0.0006595510436289046, 'gbm_weight': 0.012942252045876759}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:33:54,718] Trial 43 finished with value: 0.649049543284965 and parameters: {'cat_depth': 5, 'cat_learning_rate': 4.135187918364583e-05, 'cat_iterations': 1110, 'cat_l2_leaf_reg': 1, 'cat_border_count': 128, 'lgb_num_leaves': 43, 'lgb_max_depth': 7, 'lgb_learning_rate': 0.03489170336877375, 'lgb_n_estimators': 84, 'lgb_min_child_samples': 89, 'lgb_subsample': 0.7, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.30000000000000004, 'lgb_reg_lambda': 0.5, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.013072329152079506, 'xgb_n_estimators': 987, 'xgb_min_child_weight': 7, 'xgb_subsample': 0.555526494773299, 'xgb_colsample_bytree': 0.8229991387269919, 'xgb_reg_alpha': 0.43344657407617027, 'xgb_reg_lambda': 0.4689996637758168, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 2, 'rdf_max_depth': 4, 'rdf_min_samples_split': 0.8459609981754369, 'rdf_min_samples_leaf': 0.48499420013200917, 'max_features': 'log2', 'rdf_bootstrap': True, 'gbm_n_estimators': 974, 'gbm_max_depth': 8, 'gbm_learning_rate': 0.017553496776208117, 'gbm_min_samples_split': 4, 'gbm_min_samples_leaf': 6, 'gbm_subsample': 0.8957522404367063, 'gbm_max_features': 'sqrt', 'ridge_alpha': 0.002440603201080438, 'ridge_fit_intercept': False, 'ridge_normalize': True, 'lasso_alpha': 0.019370890795419416, 'lasso_fit_intercept': True, 'lasso_normalize': True, 'cat_weight': 0.4863950888232382, 'lgb_weight': 0.015114094572915838, 'xgb_weight': 0.35514859168186635, 'rdf_weight': 0.0016739594376422966, 'ridge_weight': 0.02393302785201068, 'lasso_weight': 0.0005190877493859208, 'gbm_weight': 0.027147470708518147}. Best is trial 0 with value: 0.5449070545790077.
# [I 2023-08-19 14:37:51,521] Trial 8 pruned. Trial was pruned at iteration 0.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_58854/4220131533.py in <module>
#       8
#       9 # 最適化を実行
# ---> 10 study.optimize(objective,
#      11                n_trials=500,
#      12                timeout=None,
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     440                 If nested invocation of this method occurs.
#     441         """
# --> 442         _optimize(
#     443             study=self,
#     444             func=func,
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     101                         # Raise if exception occurred in executing the completed futures.
#     102                         for f in completed:
# --> 103                             f.result()
#     104
#     105                     futures.add(
#
# /usr/local/conda/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     436                     raise CancelledError()
#     437                 elif self._state == FINISHED:
# --> 438                     return self.__get_result()
#     439
#     440                 self._condition.wait(timeout)
#
# /usr/local/conda/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/conda/lib/python3.9/concurrent/futures/thread.py in run(self)
#      50
#      51         try:
# ---> 52             result = self.fn(*self.args, **self.kwargs)
#      53         except BaseException as exc:
#      54             self.future.set_exception(exc)
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipykernel_58854/3876760729.py in objective(trial)
#     163         xgb_weight = trial.suggest_float('xgb_weight', 0, 1 - cat_weight - lgb_weight)
#     164         rdf_weight = trial.suggest_float('rdf_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight)
# --> 165         ridge_weight = trial.suggest_float('ridge_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight)
#     166         lasso_weight = trial.suggest_float('lasso_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight - ridge_weight )
#     167         gbm_weight = trial.suggest_float('gbm_weight', 0, 1 - cat_weight - lgb_weight - xgb_weight - rdf_weight - ridge_weight - lasso_weight)
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/trial/_trial.py in suggest_float(self, name, low, high, step, log)
#     158         """
#     159
# --> 160         distribution = FloatDistribution(low, high, log=log, step=step)
#     161         suggested_value = self._suggest(name, distribution)
#     162         self._check_distribution(name, distribution)
#
# /usr/local/conda/lib/python3.9/site-packages/optuna/distributions.py in __init__(self, low, high, log, step)
#     140
#     141         if low > high:
# --> 142             raise ValueError(
#     143                 "The `low` value must be smaller than or equal to the `high` value "
#     144                 "(low={}, high={}).".format(low, high)
#
# ValueError: The `low` value must be smaller than or equal to the `high` value (low=0, high=-0.15892913389151941).

# %%
print('  Value: ', study.best_trial.value)
print('Best trial:', study.best_trial.params)

print('cat_weight=', study.best_trial.params['cat_weight'])
print('lgb_weight=', study.best_trial.params['lgb_weight'])
print('xgb_weight=', study.best_trial.params['xgb_weight'])
print('rdf_weight=', study.best_trial.params['rdf_weight'])
print('ridge_weight=', study.best_trial.params['ridge_weight'])
print('lasso_weight=', 1 - study.best_trial.params['cat_weight'] - study.best_trial.params['lgb_weight'] - study.best_trial.params['xgb_weight'] - study.best_trial.params['rdf_weight'] - study.best_trial.params['ridge_weight'])
# Out:
#   Value:  0.474496592104912
# Best trial: {'cat_depth': 7, 'cat_learning_rate': 0.011274355582039503, 'cat_iterations': 1226, 'cat_l2_leaf_reg': 11, 'cat_border_count': 32, 'lgb_num_leaves': 24, 'lgb_max_depth': 5, 'lgb_learning_rate': 0.06286827443155239, 'lgb_n_estimators': 99, 'lgb_min_child_samples': 75, 'lgb_subsample': 0.8, 'lgb_colsample_bytree': 0.6000000000000001, 'lgb_reg_alpha': 0.0, 'lgb_reg_lambda': 0.4, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.0013235141041058147, 'xgb_n_estimators': 525, 'xgb_min_child_weight': 4, 'xgb_subsample': 0.5271654583372686, 'xgb_colsample_bytree': 0.9996640851311875, 'xgb_reg_alpha': 0.013522549859538102, 'xgb_reg_lambda': 0.022319512859360957, 'xgb_booster': 'gbtree', 'rdf_n_estimators': 44, 'rdf_max_depth': 30, 'rdf_min_samples_split': 0.9718041652771578, 'rdf_min_samples_leaf': 0.49375371323353406, 'max_features': 'auto', 'rdf_bootstrap': False, 'ridge_alpha': 0.0547728225240236, 'ridge_fit_intercept': True, 'ridge_normalize': False, 'lasso_alpha': 1.210816463460278, 'lasso_fit_intercept': False, 'lasso_normalize': True, 'cat_weight': 0.17978895652522353, 'lgb_weight': 0.30992005533493633, 'xgb_weight': 0.5075592558820964, 'rdf_weight': 0.0025800151923603006, 'ridge_weight': 0.0001500698439057882}
# cat_weight= 0.17978895652522353
# lgb_weight= 0.30992005533493633
# xgb_weight= 0.5075592558820964
# rdf_weight= 0.0025800151923603006
# ridge_weight= 0.0001500698439057882
# lasso_weight= 1.647221477613179e-06

# %%
path = 'weighted_ave(all_data1)'

# 最適なトライアルのハイパーパラメータを取得
best_params = study.best_trial.params

# モデルを保存するディレクトリのパスを設定
directory_path = f'../../model/{path}/'
# 指定したディレクトリが存在しない場合、ディレクトリを作成
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    
# CatBoostモデルのハイパーパラメータを設定して保存
cat_params = {
    'depth': best_params['cat_depth'],
    'learning_rate': best_params['cat_learning_rate'],
    'iterations': best_params['cat_iterations'],
    'l2_leaf_reg': best_params['cat_l2_leaf_reg'],
    'border_count': best_params['cat_border_count'],
    'thread_count': 4,
    'verbose': False
}
cat_best_model = CatBoostRegressor(**cat_params)
cat_best_model.fit(X, y, verbose=False)
# モデルを指定したパスに保存
cat_best_model.save_model(f'../../model/{path}/catboost.cbm')

# LightGBMモデルのハイパーパラメータを設定して保存
lgb_params = {
    'num_leaves': best_params['lgb_num_leaves'],
    'max_depth': best_params['lgb_max_depth'],
    'learning_rate': best_params['lgb_learning_rate'],
    'n_estimators': best_params['lgb_n_estimators'],
    'min_child_samples': best_params['lgb_min_child_samples'],
    'subsample': best_params['lgb_subsample'],
    'colsample_bytree': best_params['lgb_colsample_bytree'],
    'reg_alpha': best_params['lgb_reg_alpha'],
    'reg_lambda': best_params['lgb_reg_lambda'],
    'force_col_wise': True,
    'verbose': -1
}
lgb_best_model = LGBMRegressor(**lgb_params)
lgb_best_model.fit(X, y)
# モデルを指定したパスに保存
lgb_best_model.booster_.save_model(f'../../model/{path}/lightGBM.bin')

# XGBoostモデルのハイパーパラメータを設定して保存
xgb_params = {
    'max_depth': best_params['xgb_max_depth'],
    'learning_rate': best_params['xgb_learning_rate'],
    'n_estimators': best_params['xgb_n_estimators'],
    'min_child_weight': best_params['xgb_min_child_weight'],
    'subsample': best_params['xgb_subsample'],
    'colsample_bytree': best_params['xgb_colsample_bytree'],
    'reg_alpha': best_params['xgb_reg_alpha'],
    'reg_lambda': best_params['xgb_reg_lambda'],
    'verbosity': 0,
    'objective': 'reg:squarederror',
    'booster': best_params['xgb_booster'],
    'tree_method': 'hist',
    'seed': 42
}
dtrain = xgb.DMatrix(X, label=y)
xgb_best_model = xgb.train(xgb_params, dtrain, verbose_eval=False)
# モデルを指定したパスに保存
xgb_best_model.save_model(f'../../model/{path}/XGBoost.xgb')
# Out:
#   File "/tmp/ipykernel_478792/2218431985.py", line 7
#     directory_path = f'../../model/{pa th}/'
#         ^
# SyntaxError: f-string: invalid syntax
# 現在のセルまたは前のセルでコードを実行中に、カーネルがクラッシュしました。エラーの原因を特定するには、セル内のコードを確認してください。詳細については、<a href='https://aka.ms/vscodeJupyterKernelCrash'>こちら</a> をクリックしてください。さらなる詳細については、Jupyter [log] (command:jupyter.viewOutput) を参照してください。
